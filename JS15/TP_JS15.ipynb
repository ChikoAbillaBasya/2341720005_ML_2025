# %% [markdown]
# <a href="https://colab.research.google.com/drive/1DcH9QM0FP-FjFSmvo5-hTLt2cdSueUgW?usp=drive_link" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Tugas Praktikum - Deploy Model Batik Classifier**
#
# ### **Metadata Deployment**
#
# | **Property** | **Value** |
# |--------------|-----------|
# | Title | Batik Classifier Kelompok 1 |
# | Emoji | 🏢 |
# | Color From | Blue |
# | Color To | Gray |
# | SDK | Docker |
# | Pinned | False |
# | License | Apache-2.0 |
#
# ### **Identitas**
#
# | **Keterangan** | **Detail** |
# |----------------|------------|
# | Nama | Chiko Abilla Basya |
# | NIM | 2341720005 |
# | Kelas | TI 3G |
# | No. Absen | 09 |
# | Kelompok | 1 |
#
# ### **Link Deployment**
#
# | **Platform** | **Link** |
# |--------------|----------|
# | 🔗 Hugging Face Space | [Batik Classifier](https://huggingface.co/spaces/Rasomon/ml-batik-classifier) |
#
# ### **Hasil Deploy**
#
# ![TP_JS15_1.png](attachment:TP_JS15_1.png)
#
# ![TP_JS15_2.png](attachment:TP_JS15_2.png)
